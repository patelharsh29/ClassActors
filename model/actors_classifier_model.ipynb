# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/Beautiful Smile of Bollywood- Tara Sutaria.jpg')
img.shape
# Out:
# (225, 225, 3)

# %%
plt.imshow(img)
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (225, 225)

# %%
gray
# Out:
# array([[239, 239, 239, ..., 242, 242, 242],
#        [239, 239, 239, ..., 242, 242, 242],
#        [239, 239, 239, ..., 242, 242, 242],
#        ...,
#        [214, 213, 212, ...,  56,  80, 118],
#        [213, 212, 212, ...,  56,  72, 104],
#        [211, 210, 209, ...,  42,  62,  97]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')
plt.show()

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 43,  41, 105, 105]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (43, 41, 105, 105)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)
plt.show()

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')
plt.show()

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (105, 105, 3)

# %%
def get_cropped_image_if_2_eyes(image_path):
    if not os.path.exists(image_path):
        return None
    img = cv2.imread(image_path)
    if img is None:
        return None
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/Beautiful Smile of Bollywood- Tara Sutaria.jpg')
plt.imshow(original_image)
plt.show()

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/Beautiful Smile of Bollywood- Tara Sutaria.jpg')
plt.imshow(cropped_image)
plt.show()

# %%
org_image_obstructed = cv2.imread('./test_images/com_ (7).jpg')
plt.imshow(org_image_obstructed)
plt.show()

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/com_ (7).jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/alia_bhatt',
#  './dataset/varun_dhawan',
#  './dataset/tara_sutaria',
#  './dataset/hrithik_roshan',
#  './dataset/tiger_shroff',
#  './dataset/cropped']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/alia_bhatt
# Generating cropped images in folder:  ./dataset/cropped/varun_dhawan
# Generating cropped images in folder:  ./dataset/cropped/tara_sutaria
# Generating cropped images in folder:  ./dataset/cropped/hrithik_roshan
# Generating cropped images in folder:  ./dataset/cropped/tiger_shroff

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'alia_bhatt': ['./dataset/cropped/alia_bhatt/alia_bhatt6.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt27.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt33.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt32.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt26.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt7.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt5.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt109.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt30.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt24.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt18.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt19.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt25.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt31.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt108.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt4.png',
#   './dataset/cropped/alia_bhatt/.DS_Store',
#   './dataset/cropped/alia_bhatt/alia_bhatt35.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt21.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt118.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt20.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt34.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt1.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt3.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt22.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt36.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt37.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt23.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt2.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt44.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt50.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt78.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt87.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt93.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt92.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt86.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt79.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt51.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt45.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt53.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt47.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt90.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt85.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt91.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt46.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt52.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt42.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt95.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt81.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt80.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt94.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt43.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt57.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt69.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt41.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt55.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt82.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt96.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt97.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt83.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt54.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt40.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt68.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt65.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt59.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt58.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt70.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt64.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt72.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt66.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt99.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt98.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt67.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt73.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt77.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt63.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt88.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt89.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt62.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt76.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt48.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt60.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt74.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt75.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt61.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt12.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt103.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt117.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt116.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt102.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt13.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt114.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt100.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt39.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt38.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt101.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt115.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt10.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt9.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt111.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt105.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt14.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt104.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt110.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt8.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt106.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt112.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt17.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt16.png',
#   './dataset/cropped/alia_bhatt/alia_bhatt107.png'],
#  'varun_dhawan': ['./dataset/cropped/varun_dhawan/varun_dhawan19.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan25.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan31.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan30.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan24.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan32.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan26.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan27.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan33.png',
#   './dataset/cropped/varun_dhawan/.DS_Store',
#   './dataset/cropped/varun_dhawan/varun_dhawan8.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan37.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan23.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan22.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan36.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan9.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan34.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan35.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan21.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan46.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan52.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan53.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan47.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan51.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan45.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan44.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan54.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan40.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan41.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan55.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan43.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan57.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan42.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan49.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan48.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan7.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan38.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan10.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan6.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan4.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan13.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan12.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan5.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan1.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan17.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan2.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan15.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan29.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan28.png',
#   './dataset/cropped/varun_dhawan/varun_dhawan3.png'],
#  'tara_sutaria': ['./dataset/cropped/tara_sutaria/tara_sutaria5.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria23.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria37.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria36.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria22.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria4.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria6.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria34.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria20.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria21.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria7.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria3.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria31.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria25.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria19.png',
#   './dataset/cropped/tara_sutaria/.DS_Store',
#   './dataset/cropped/tara_sutaria/tara_sutaria18.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria24.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria30.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria26.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria32.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria33.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria27.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria1.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria68.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria40.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria54.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria55.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria41.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria69.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria43.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria42.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria56.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria52.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria47.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria53.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria45.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria51.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria50.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria44.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria49.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria61.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria60.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria48.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria62.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria63.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria67.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria66.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria64.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria58.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria59.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria71.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria16.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria17.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria29.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria15.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria14.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria28.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria10.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria38.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria39.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria11.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria9.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria13.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria12.png',
#   './dataset/cropped/tara_sutaria/tara_sutaria8.png'],
#  'hrithik_roshan': ['./dataset/cropped/hrithik_roshan/hrithik_roshan1.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan12.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan13.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan2.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan11.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan39.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan38.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan3.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan7.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan28.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan14.png',
#   './dataset/cropped/hrithik_roshan/.DS_Store',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan15.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan29.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan6.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan4.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan16.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan5.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan65.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan71.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan59.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan58.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan70.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan64.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan72.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan67.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan73.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan77.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan63.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan88.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan89.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan62.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan76.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan48.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan60.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan74.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan75.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan61.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan49.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan44.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan50.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan78.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan87.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan93.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan92.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan86.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan79.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan51.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan45.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan53.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan47.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan90.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan84.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan85.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan91.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan46.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan56.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan42.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan81.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan80.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan43.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan57.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan69.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan55.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan82.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan83.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan54.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan40.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan8.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan27.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan33.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan32.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan26.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan9.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan30.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan18.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan19.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan25.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan31.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan35.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan21.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan20.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan22.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan36.png',
#   './dataset/cropped/hrithik_roshan/hrithik_roshan37.png'],
#  'tiger_shroff': ['./dataset/cropped/tiger_shroff/tiger_shroff3.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff2.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff1.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff5.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff4.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff6.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff7.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff24.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff30.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff18.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff19.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff31.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff25.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff33.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff27.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff26.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff32.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff36.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff22.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff23.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff37.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff21.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff35.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff34.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff20.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff11.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff38.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff10.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff12.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff13.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff17.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff16.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff28.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff14.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff15.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff29.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff9.png',
#   './dataset/cropped/tiger_shroff/tiger_shroff8.png']}

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')
plt.show()

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'alia_bhatt': 0,
#  'varun_dhawan': 1,
#  'tara_sutaria': 2,
#  'hrithik_roshan': 3,
#  'tiger_shroff': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X)
# Out:
# 345

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[  2],
#        [  6],
#        [ 55],
#        ...,
#        [172],
#        [173],
#        [ 13]], dtype=uint8)

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (345, 4096)

# %%
X[0]
# Out:
# array([  2.,   6.,  55., ..., 172., 173.,  13.])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.6666666666666666

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.76      0.74        33
#            1       0.50      0.40      0.44        10
#            2       0.67      0.62      0.65        16
#            3       0.70      0.73      0.71        22
#            4       0.50      0.50      0.50         6
#
#     accuracy                           0.67        87
#    macro avg       0.62      0.60      0.61        87
# weighted avg       0.66      0.67      0.66        87

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/envs/classActors/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#                  model  best_score  \
# 0                  svm    0.705581
# 1        random_forest    0.437783
# 2  logistic_regression    0.651056
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, multi_class='auto',
#                                      solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7241379310344828

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.4942528735632184

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7586206896551724

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[27,  1,  5,  0,  0],
#        [ 0,  8,  0,  2,  0],
#        [ 5,  0, 10,  1,  0],
#        [ 1,  4,  0, 17,  0],
#        [ 1,  2,  0,  2,  1]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
plt.close()

# %%
class_dict
# Out:
# {'alia_bhatt': 0,
#  'varun_dhawan': 1,
#  'tara_sutaria': 2,
#  'hrithik_roshan': 3,
#  'tiger_shroff': 4}

# %%
# !pip install joblib
import joblib
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in /opt/anaconda3/envs/classActors/lib/python3.10/site-packages (1.4.2)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
